# %%
class python:
<<<<<<< current
    def __init__(self, message=None):
         if not message:
            print("This is a lot of text")
=======
    def __init__(self, message:str):
        if not message:
            print("This is a lot of text")
        else:
            print(message) 
>>>>>>> incoming

# %%
<<<<<<< current
second = python("Message here!")
=======
first = python("This is a bit of text")
>>>>>>> incoming
# Out:
# <<<<<<< current <removed>
# ...
# This is a bit of text
# >>>>>>> incoming <modified: >
