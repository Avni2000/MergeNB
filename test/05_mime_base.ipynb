# %% [markdown]
# # MergeNB Rendermime Integration Fixture
# ![logo](logo.svg)
# $$E = mc^2$$

# %%
value = 'base'\n# MIME_CONFLICT_OUTPUT_SENTINEL\nvalue
# Out:
# STREAM_ARRAY_LINE_1\nSTREAM_ARRAY_LINE_2\n
# PLAIN_ARRAY_LINE_1\nPLAIN_ARRAY_LINE_2
# HTML_RENDER_OK
# PNG_RENDER_OK
# SVG_RENDER_OK
# JSON_RENDER_OK

# %%
# MIME_OUTPUT_SHOWCASE\nprint('MIME_OUTPUT_SENTINEL')
# Out:
# STREAM_ARRAY_LINE_1\nSTREAM_ARRAY_LINE_2\n
# PLAIN_ARRAY_LINE_1\nPLAIN_ARRAY_LINE_2
# HTML_RENDER_OK
# PNG_RENDER_OK
# SVG_RENDER_OK
# JSON_RENDER_OK
